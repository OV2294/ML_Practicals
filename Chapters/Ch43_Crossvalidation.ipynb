# %%
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd

# %%
iris = load_iris()
X = iris.data
y = iris.target

# %%
scalar = StandardScaler()
X_scaled = scalar.fit_transform(X)

# %%
X_scaled_df = pd.DataFrame(
    X_scaled,
    columns = iris.feature_names
)

X_scaled_df["target"] = y
X_scaled_df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
print("Columns: ", X_scaled_df.columns.tolist())
print("\nInfo: ",X_scaled_df.info())
print("\nDescribe: ",X_scaled_df.describe())
# Out:
# Columns:  ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)', 'target']
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
#  4   target             150 non-null    int64
# dtypes: float64(4), int64(1)
# memory usage: 6.0 KB
#
# Info:  None
#
# Describe:         sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count       1.500000e+02      1.500000e+02       1.500000e+02
# mean       -1.468455e-15     -1.823726e-15      -1.610564e-15
# std         1.003350e+00      1.003350e+00       1.003350e+00
# min        -1.870024e+00     -2.433947e+00      -1.567576e+00
# ...

# %%
model = LogisticRegression(max_iter = 1000)

# %%
kf = KFold(n_splits=5, shuffle = True, random_state= 1)
scores = cross_val_score(model, X_scaled, y, cv=kf)
print("Accuracy for each fold: ", scores)
print("\nAverage Accuracy: ", scores.mean())
# Out:
# Accuracy for each fold:  [0.96666667 0.96666667 0.96666667 0.93333333 0.93333333]
#
# Average Accuracy:  0.9533333333333334

# %%
skf = StratifiedKFold(n_splits=5, shuffle = True, random_state= 1)
scores1 = cross_val_score(model, X_scaled, y, cv=skf)
print("Accuracy for each fold: ", scores1)
print("\nAverage Accuracy: ", scores1.mean())
# Out:
# Accuracy for each fold:  [0.96666667 1.         0.96666667 0.96666667 0.9       ]
#
# Average Accuracy:  0.9600000000000002

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, train_size=0.2, random_state=1)
model.fit(X_train, y_train)
print("SIngle Split Accuracy: ", model.score(X_test,y_test))
# Out:
# SIngle Split Accuracy:  0.925
