# %%
import sys
import numpy as np
import pandas as pd
import matplotlib
import sklearn

# %%
data = pd.read_csv('Handbooks\ML\Old Datasets 06.12.25\student_scores.csv')
print(data.head(10))
# Out:
#      name  hours  score gender grades class
# 0   Aarav      8     76      M      A    9A
# 1    Riya      5     62      F      B    9B
# 2   Kabir     10     88      M      A   10A
# 3    Sana      4     55      F      C    9A
# 4  Vivaan      7     72      M      B   10B
# 5  Ishita      6     64      F      B    9C
# 6   Rohan      3     48      M      D    9B
# 7   Meera      9     90      F      A   11A
# 8  Aditya      2     38      M      F    9C
# 9   Kavya     11     93      F      A   12A
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# <>:1: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\ITCS\AppData\Local\Temp\ipykernel_12560\4025795096.py:1: SyntaxWarning: invalid escape sequence '\M'
#   data = pd.read_csv('Handbooks\ML\Old Datasets 06.12.25\student_scores.csv')
