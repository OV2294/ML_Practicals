# %%
import pandas as pd
import optuna
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score

# Step 1: Create Data
# Here model learn Pattern So the model learns this pattern:
data = {
    "attendance": [85, 60, 72, 40, 90, 55, 78, 40, 70, 34],
    "result": ["Pass", "Fail", "Pass", "Fail", "Pass", "Fail", "Pass", "Fail", "Pass", "Fail"]
}

df = pd.DataFrame(data)

X = df[['attendance']]
y = df['result']

# Step 2: Define Objective Function
def objective(trial):
    max_depth = trial.suggest_int('max_depth', 1, 5)
    criterion = trial.suggest_categorical('criterion', ['gini', 'entropy'])

    model = DecisionTreeClassifier(max_depth=max_depth, criterion=criterion)

    score = cross_val_score(model, X, y, cv=2)
    return score.mean()

# Step 3: Run Optuna
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=2)

# Step 4: Best Result
print("Best Parameters:", study.best_params)
print("Best Accuracy:", study.best_value)
# Out:
# [I 2026-03-23 12:58:51,229] A new study created in memory with name: no-name-981cd5ab-ffa7-4e42-8027-9a4623df0d65
# [I 2026-03-23 12:58:51,244] Trial 0 finished with value: 0.8333333333333333 and parameters: {'max_depth': 2, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8333333333333333.
# [I 2026-03-23 12:58:51,258] Trial 1 finished with value: 0.8333333333333333 and parameters: {'max_depth': 5, 'criterion': 'entropy'}. Best is trial 0 with value: 0.8333333333333333.
# Best Parameters: {'max_depth': 2, 'criterion': 'entropy'}
# Best Accuracy: 0.8333333333333333
